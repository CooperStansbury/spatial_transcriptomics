# %%
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches 

import utils as ut

# %%
plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 3, 3

cmap = plt.cm.get_cmap('viridis', 4)

handles = []

for c, key in zip(np.linspace(0, 0.5, 3), ['ND', '8w', '14w']):
    patch = mpatches.Patch(color=cmap(c), label=key, alpha=0.5)
    handles.append(patch)
    
plt.legend(handles=handles, frameon=False)
plt.axis(False)
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
plt.clf()

# %%
plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 3, 3


cellTypes = [
    'B cells',
    'Dendritic cells',
    'Macrophages',
    'Monocytes',
    'NK cells',
    'Other',
    'T cells',
]


ut.COLORS

handles = []

for c, key in zip(ut.COLORS, cellTypes):
    patch = mpatches.Patch(color=c, label=key, lw=1, ec='k')
    handles.append(patch)
    
plt.legend(handles=handles, frameon=False)
plt.axis(False)


# handles = []

# for c, key in zip(np.linspace(0, 0.5, 3), ['ND', '8w', '14w']):
#     patch = mpatches.Patch(color=cmap(c), label=key, alpha=0.5)
#     handles.append(patch)
    
# plt.legend(handles=handles, frameon=False)
# plt.axis(False)
# Out:
# (0.0, 1.0, 0.0, 1.0)
