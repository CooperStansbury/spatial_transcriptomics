# %%
import os
import pandas as pd
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc
from collections import Counter
import squidpy as sq
from scipy.spatial.distance import pdist, squareform
import scipy
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
from sklearn import metrics
import tabulate
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram
import itertools
import umap
from importlib import reload
from scipy import stats
import matplotlib.image as mpimg
import gget

# locals
import utils as ut
reload(ut)
# Out:
# 2022-11-29 10:03:37.952844: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-29 10:03:38.082921: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/slurm/lib64:
# 2022-11-29 10:03:38.082942: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-11-29 10:03:38.108670: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
clusterPath = "/nfs/turbo/umms-indikar/shared/projects/spatial_transcriptomics/data/scanpy/clusters.csv"
cf = pd.read_parquet(clusterPath)
print(cf.shape)
print(cf['cellType'].unique())
cf.head()
# Out:
# (427882, 7)
# ['Macrophages' 'B cells' 'Monocytes' 'NK cells' 'Dendritic cells'
#  'T cells' 'Stromal cells']
#      gene     scores          pvals  logfoldchanges  clusterId key  \
# 0  H2-EB1  36.343353  4.575346e-181        3.564091          1  ND
# 1   H2-AA  35.311523  4.761517e-183        3.430534          1  ND
# 2  H2-AB1  34.411163  2.815112e-177        3.234597          1  ND
# 3    CD74  33.910587  2.451588e-177        3.302062          1  ND
# 4  H2-DMA  31.695400  2.991793e-123        2.667091          1  ND
#
#       cellType
# 0  Macrophages
# 1  Macrophages
# 2  Macrophages
# 3  Macrophages
# 4  Macrophages

# %%
t = cf[['cellType', 'clusterId', 'key']].drop_duplicates()
t = t.groupby(['cellType', 'key'])['clusterId'].count().reset_index()
t = t.sort_values(by=['key', 'cellType'], ascending=[False, True])

colorlist = ut.ncolor(3, cmap='viridis')


plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 5, 3

sns.barplot(data=t,
            y='clusterId',
            x='cellType',
            hue='key',
            edgecolor='k',
            palette=colorlist)

plt.ylabel("Number of Clusters")
plt.xlabel("")
_ = plt.xticks(rotation=45)

ax = plt.gca()
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles[0:], labels=labels[0:])

# t = pd.pivot_table(t, values='clusterId', index=['cellType'],
#                     columns=['key']).reset_index()

# # reorder columns
# t = t[['cellType', 'ND', 'HFD8', 'HFD14']].rename(columns={'cellType' : 'Cell Type'})

# print(tabulate.tabulate(t,  headers=t.columns, tablefmt='latex'))

# %%
""" get ND cells """
alpha = 0.05
cellType = 'Macrophages'
# cellType = 'Monocytes'

keys = ['ND', 'HFD8', 'HFD14']

res = {}

for key in keys:

    t = cf[cf['cellType'] == cellType].reset_index(drop=True)
    t = t[t['key'] == key].reset_index(drop=True)
    nClusters = t['clusterId'].nunique()
    t['geneCount'] = t.groupby('gene')['clusterId'].transform('count')

    t = t[t['pvals'] < alpha] # only singificant results

    uni = t[t['geneCount'] < 2] # single cluster
    shared = t[t['geneCount'] > (nClusters-1)] # all clusters
    
    print(key)
    print(f"{uni.shape} {uni['gene'].nunique()}")
    print(f"{shared.shape} {shared['gene'].nunique()}")
    
    res[key] = [uni, shared]
    
    print()
# Out:
# ND
# (4212, 8) 4212
# (3824, 8) 956
#
# HFD8
# (1185, 8) 1185
# (2920, 8) 365
#
# HFD14
# (1224, 8) 1224
# (3912, 8) 489

# %%
"""shared gene analysis """
n = 500
lft = 1
db = 'celltypes'
keys = ['ND', 'HFD8', 'HFD14']

allMarker = []
allLF = []

for key in keys:
    uni, shared = res[key]
    shared = shared.sort_values(by='scores', ascending=False)
    genes = shared['gene'].head(n).to_list()
    
    lfGenes = list(set(shared[shared['logfoldchanges'] > lft]['gene'].to_list()))
    allLF += lfGenes
    kegg = gget.enrichr(genes, database=db)
    
    # get genes for the cell type pathway
    mGenes = kegg[kegg['path_name'] == cellType]['overlapping_genes'].values[0]
    allMarker += mGenes
    print(key, len(mGenes))
    print(kegg[['path_name', 'p_val']].head(10))
    print()
    

# genes with LFC > lft in ll three times points
allLF = pd.DataFrame.from_dict(Counter(allLF), orient='index', columns=['count']).reset_index()
allLF = allLF[allLF['count'] > 2]['index'].to_list()
print(", ".join(sorted(allLF)))
print()

# genes also included in the celltype
allMarker = pd.DataFrame.from_dict(Counter(allMarker), orient='index', columns=['count']).reset_index()
allMarker = allMarker[allMarker['count'] > 2]['index'].to_list()
print(", ".join(sorted(allMarker)))
# Out:
# Tue Nov 29 10:03:40 2022 INFO Performing Enichr analysis using database PanglaoDB_Augmented_2021.
#     Please note that there might a more appropriate database for your application.
#     Go to https://maayanlab.cloud/Enrichr/#libraries for a full list of supported databases.
#
# Tue Nov 29 10:03:41 2022 INFO Performing Enichr analysis using database PanglaoDB_Augmented_2021.
#     Please note that there might a more appropriate database for your application.
#     Go to https://maayanlab.cloud/Enrichr/#libraries for a full list of supported databases.
# ND 38
#                     path_name         p_val
# 0                 Macrophages  1.174358e-29
# 1             Dendritic Cells  7.275703e-29
# 2                   Monocytes  1.398361e-23
# 3                   Microglia  1.787250e-21
# 4               Kupffer Cells  1.907555e-18
# 5        Alveolar Macrophages  2.163172e-18
# 6        Red Pulp Macrophages  2.625221e-18
# 7  Osteoclast Precursor Cells  2.368250e-17
# ...

# %%
# break

# %%
"""Next we look at unique genes """

lft = 1
db = 'celltypes'
keys = ['ND', 'HFD8', 'HFD14']

plt.rcParams['figure.dpi'] = 300


for key in keys:
    uni, shared = res[key]
    
    
    # add LF flag
    uni['lfc'] = np.where(uni['logfoldchanges'] > lft, 1, 0)
    
    # DE genes
    gr = uni.groupby(['clusterId']).agg(
        nGene = ('gene', 'count'),
        lfcGene = ('lfc', 'sum') 
    ).reset_index()
    
    gr = gr.sort_values(by='clusterId')
    
    
    gr['label'] = gr.index + 1
    gr['label'] = gr['label'].apply(lambda x: f"Cluster {x}")
    
    
    gr = gr[['label', 'nGene', 'lfcGene']].rename(columns={'label' : 'Cluster', 
                                                           'nGene': 'DE Genes', 
                                                           'lfcGene': f'LFC > {lft}'})
    
    print(tabulate.tabulate(gr, headers=gr.columns, tablefmt='latex'))
    print()
    # genes = gr['nGene'].to_list()
    # labels = gr['label'].to_list()
    
#     print(gr)
#     print()
    
#     k = len(gr)
#     colorlist = ut.ncolor(k, cmap='Spectral')
    
    
#     plt.rcParams['figure.figsize'] =  3, (k / 2)
    
#     fig, ax = plt.subplots()
    
#     ax.barh(labels,
#            genes,
#            edgecolor='k',
#            color=colorlist)
    
#     ax.set_xlabel('DE Genes')
#     ax.set_ylabel('')
#     ax.invert_yaxis()
    
#     plt.show()
#     print()
# Out:
# \begin{tabular}{rlrr}
# \hline
#     & Cluster   &   DE Genes &   LFC \ensuremath{>} 1 \\
# \hline
#   0 & Cluster 1 &        666 &        73 \\
#   1 & Cluster 2 &        671 &       323 \\
#   2 & Cluster 3 &        219 &        56 \\
#   3 & Cluster 4 &       2656 &         0 \\
# \hline
# \end{tabular}
#
# \begin{tabular}{rlrr}
# \hline
#     & Cluster   &   DE Genes &   LFC \ensuremath{>} 1 \\
# \hline
#   0 & Cluster 1 &        310 &        82 \\
#   1 & Cluster 2 &         66 &         7 \\
#   2 & Cluster 3 &        124 &        15 \\
#   3 & Cluster 4 &        187 &        12 \\
#   4 & Cluster 5 &         86 &         9 \\
#   5 & Cluster 6 &         89 &         9 \\
#   6 & Cluster 7 &        145 &         7 \\
#   7 & Cluster 8 &        178 &        12 \\
# \hline
# \end{tabular}
#
# \begin{tabular}{rlrr}
# \hline
#     & Cluster   &   DE Genes &   LFC \ensuremath{>} 1 \\
# \hline
#   0 & Cluster 1 &        140 &        31 \\
# ...

# %%
"""Next we look at unique genes """

lft = 1
alpha = 0.05
# db = 'WikiPathways_2019_Mouse'
# db = 'KEGG_2019_Mouse'
db = 'ontology'

keys = ['ND', 'HFD8', 'HFD14']

plt.rcParams['figure.dpi'] = 300

lfGene = {}
allGene = {}
dfList = []


for key in keys:
    uni, shared = res[key]
    
    
    for cid in uni['clusterId'].unique():
        t = uni[uni['clusterId'] == cid]
        
        t = t.sort_values(by='logfoldchanges', ascending=False)
        mGenes = t['gene'].to_list()
        
        if not key in allGene:
            allGene[key] = {cid: mGenes}
        else:
            allGene[key][cid] = mGenes
        
        # genes passing lf filter
        t = t[t['logfoldchanges'] > lft]
        
        if len(t) > 0:
            t = t.sort_values(by='logfoldchanges', ascending=False)
            lfcGenes = t['gene'].to_list()

            if not key in lfGene:
                lfGene[key] = {cid: lfcGenes}
            else:
                lfGene[key][cid] = lfcGenes

        # enrichment analysis
        ef = gget.enrichr(mGenes, database=db)
        ef = ef[ef['p_val'] < alpha]
        ef['key'] = key
        ef['clusterId'] = cid
        ef['allDEG'] = ", ".join(mGenes)
        ef['LFCGenes'] = ", ".join(lfcGenes)
        dfList.append(ef)
        
df = pd.concat(dfList, ignore_index=True)
print(df.shape)
outpath = f"/nfs/turbo/umms-indikar/shared/projects/spatial_transcriptomics/data/scanpy/{cellType}_DE_{db}.csv"
df.to_csv(outpath, index=False)
df.head()
# Out:
# Tue Nov 29 10:03:42 2022 INFO Performing Enichr analysis using database GO_Biological_Process_2021.
#     Please note that there might a more appropriate database for your application.
#     Go to https://maayanlab.cloud/Enrichr/#libraries for a full list of supported databases.
#
# Tue Nov 29 10:03:43 2022 INFO Performing Enichr analysis using database GO_Biological_Process_2021.
#     Please note that there might a more appropriate database for your application.
#     Go to https://maayanlab.cloud/Enrichr/#libraries for a full list of supported databases.
#
# Tue Nov 29 10:03:45 2022 INFO Performing Enichr analysis using database GO_Biological_Process_2021.
#     Please note that there might a more appropriate database for your application.
#     Go to https://maayanlab.cloud/Enrichr/#libraries for a full list of supported databases.
#
# Tue Nov 29 10:03:45 2022 INFO Performing Enichr analysis using database GO_Biological_Process_2021.
# ...

# %%
# keys = ['ND', 'HFD8', 'HFD14']

# res = []


# for key in keys:
#     uni, shared = res[key]
    
    
    
#     for cid in uni['clusterId'].unique():
        
#         cdf = uni[uni['clusterId'] == cid]
#         cdf = cdf.sort_values(by='logfoldchanges', ascending=False)
        
#         mGenes = ", ".join(cdf['gene'].to_list())
        
#         row = {
#             'time' : key,
#             'clusterId' : 
#         }
        
        
        
        
#         print(cid, "\t&\t", ", ".join(mGenes))
#         # print("\n".join(mGenes))
#         # print()

# %%
nd = df[df['key'] == 'ND'].reset_index(drop=True)
nd['nOverlap'] = nd['overlapping_genes'].apply(lambda x: len(x))

for i, cid in enumerate(nd['clusterId'].unique()):
    
    cdf = nd[nd['clusterId'] == cid]
    
    for j in range(8):
        print(f"{cid} cluster {i+1}", cdf.iloc[j]['path_name'])
        
    print()
# Out:
# 1 cluster 1 mRNA splicing, via spliceosome (GO:0000398)
# 1 cluster 1 RNA splicing, via transesterification reactions with bulged adenosine as nucleophile (GO:0000377)
# 1 cluster 1 mRNA processing (GO:0006397)
# 1 cluster 1 gene expression (GO:0010467)
# 1 cluster 1 spliceosomal snRNP assembly (GO:0000387)
# 1 cluster 1 translational termination (GO:0006415)
# 1 cluster 1 ribonucleoprotein complex assembly (GO:0022618)
# 1 cluster 1 mitochondrial translational elongation (GO:0070125)
#
# 3 cluster 2 ubiquitin-dependent protein catabolic process (GO:0006511)
# 3 cluster 2 post-Golgi vesicle-mediated transport (GO:0006892)
# 3 cluster 2 glycerophospholipid biosynthetic process (GO:0046474)
# 3 cluster 2 regulation of cellular component organization (GO:0051128)
# 3 cluster 2 modification-dependent protein catabolic process (GO:0019941)
# 3 cluster 2 proteasome-mediated ubiquitin-dependent protein catabolic process (GO:0043161)
# ...

# %%
lft = 0
keys = ['ND', 'HFD8', 'HFD14']

allGene = {}

for key in keys:
    uni, shared = res[key]
    
    for cid in uni['clusterId'].unique():
        uniG = uni[(uni['clusterId'] == cid) & (uni['logfoldchanges'] > lft)]
        uniG = uniG['gene'].to_list()
        
            
        sharedG = shared[(shared['clusterId'] == cid) & (shared['logfoldchanges'] > lft)]
        sharedG = sharedG['gene'].to_list()
        
        print(f"{key} {cid} {len(uniG)} {len(sharedG)}")
        
        mGenes = list(set(uniG + sharedG))
        
        
        if not key in allGene:
            allGene[key] = {cid: mGenes}
        else:
            allGene[key][cid] = mGenes

        
print('done')
# Out:
# ND 1 565 265
# ND 3 594 183
# ND 11 73 165
# ND 15 1 74
# HFD8 4 267 180
# HFD8 6 15 160
# HFD8 8 20 79
# HFD8 10 182 283
# HFD8 11 13 147
# HFD8 12 12 151
# HFD8 14 13 164
# HFD8 22 12 158
# HFD14 1 106 154
# HFD14 2 10 142
# HFD14 3 21 152
# HFD14 5 195 181
# HFD14 6 169 428
# HFD14 9 29 166
# HFD14 10 51 170
# HFD14 15 0 43
# done

# %%
newRows = []

for ti in allGene.keys():
    for tj in allGene.keys():
        for ci in allGene[ti]:
            for cj in allGene[tj]:


                di = set(allGene[ti][ci])
                dj = set(allGene[tj][cj])

                overlap = di.intersection(dj)
                union = di.union(dj)

                row = {
                    'key1' : ti,
                    'key2' : tj,
                    'cid1' : ci,
                    'cid2' : cj,
                    'l1' : f"{ti}_{ci}",
                    'l2' : f"{tj}_{cj}",
                    'n1' : len(di),
                    'n2' : len(dj),
                    'n_overlap' : len(overlap),
                    'n_union' : len(union),
                    'jaccard' : len(overlap) /  len(union),
                    'overlap' : list(overlap)

                }

                newRows.append(row)

df = pd.DataFrame(newRows)
print(df.shape)

df.head()

k = pd.pivot_table(df, 
                   values='jaccard', 
                   index=['l1'],
                   columns=['l2'])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 15, 15
plt.rcParams['figure.facecolor'] = "w"

sns.heatmap(k,
            annot=True, 
            linewidth=.5,
            linecolor='lightgrey',
            vmin=0,
            vmax=np.quantile(k, 0.95),
            cbar=True,
            cmap='Reds',
            cbar_kws={'fraction' : 0.046, 
                      'pad' : 0.04, 
                      'label' : 'Jaccard Similarity'},
            fmt=".1f",
            zorder=1)

plt.ylabel("")
plt.xlabel("")

# label each time point
colorlist = ut.ncolor(3, cmap='viridis')

fillalpha = 0.4

xy = 16
nclusters = len(k.columns)

plt.axvline(x=xy, c='k', lw=2)
plt.axhline(y=xy, c='k', lw=2)


xy = 8
plt.axvline(x=xy, c='k', lw=2)
plt.axhline(y=xy, c='k', lw=2)

plt.gca().set_aspect('equal')
plt.gca().invert_xaxis()
plt.gca().invert_yaxis()
# Out:
# (400, 12)

# %%
break
# Out:
#   File "/tmp/ipykernel_23759/668683560.py", line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
""" get ND cells """
cTypes = ['Monocytes', 'Macrophages']
lft = 0

keys = ['ND', 'HFD8', 'HFD14']

res = {}

for key in keys:
    
    t = cf[cf['cellType'].isin(cTypes)].reset_index(drop=True)
    t = t[t['key'] == key].reset_index(drop=True)
    
    # count the number of cell type specific clusters
    nClusters = {}
    for ctype in cTypes:
        k = t[t['cellType'] == ctype]
        k = k['clusterId'].nunique()
        nClusters[ctype] = k
        
    # make sure genes are shared across cell type clusters
    t['nCluster'] = t['cellType'].map(nClusters)
    t['geneCount'] = t.groupby(['gene', 'cellType'])['clusterId'].transform('count')
    t = t[t['logfoldchanges'] > lft] # only upregulated genes
    # t = t[t['geneCount'] > (t['nCluster']-1)] # genes shared in all clusters
    
    keyRes = {}
    
    for ctype in cTypes:
        keyRes[ctype] = t[t['cellType'] == ctype].reset_index(drop=True)
    
    # keys are time points, and cell types contain all genes
    res[key] = keyRes
    
print('done')
# Out:
# done

# %%
keys = ['ND', 'HFD8', 'HFD14']

allGene = {}

for key in keys:
    for ctype in cTypes:
        
        t = res[key][ctype]
        
        for cid in t['clusterId'].unique():
            ctid = t[t['clusterId'] == cid].reset_index(drop=True)    
            mGenes = list(set(ctid['gene']))
            newKey = f"{ctype}_{cid}"


            if not key in allGene:
                allGene[key] = {newKey: mGenes}
            else:
                allGene[key][newKey] = mGenes

        
print('done')
# Out:
# done

# %%
newRows = []

for ti in allGene.keys():
    for tj in allGene.keys():
        for ci in allGene[ti]:
            for cj in allGene[tj]:


                di = set(allGene[ti][ci])
                dj = set(allGene[tj][cj])

                overlap = di.intersection(dj)
                union = di.union(dj)

                row = {
                    'key1' : ti,
                    'key2' : tj,
                    'cid1' : ci,
                    'cid2' : cj,
                    'l1' : f"{ti}_{ci}",
                    'l2' : f"{tj}_{cj}",
                    'n1' : len(di),
                    'n2' : len(dj),
                    'n_overlap' : len(overlap),
                    'n_union' : len(union),
                    'jaccard' : len(overlap) /  len(union),
                    'overlap' : list(overlap)

                }

                newRows.append(row)

df = pd.DataFrame(newRows)
print(df.shape)

df.head()

k = pd.pivot_table(df, 
                   values='jaccard', 
                   index=['l1'],
                   columns=['l2'])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 15, 15
plt.rcParams['figure.facecolor'] = "w"

sns.heatmap(k,
            annot=True, 
            linewidth=.5,
            linecolor='lightgrey',
            vmin=0,
            vmax=np.quantile(k, 0.95),
            cbar=True,
            cmap='Reds',
            cbar_kws={'fraction' : 0.046, 
                      'pad' : 0.04, 
                      'label' : 'Jaccard Similarity'},
            fmt=".1f",
            zorder=1)

plt.ylabel("")
plt.xlabel("")


lw = 3
lc = "b"
xy = 11
plt.axvline(x=xy, c=lc, lw=lw, zorder=2)
plt.axhline(y=xy, c=lc, lw=lw, zorder=2)

xy = 23
plt.axvline(x=xy, c=lc, lw=lw, zorder=2)
plt.axhline(y=xy, c=lc, lw=lw, zorder=2)

""" Second line type"""
lw = 3
lc = "limegreen"
xy = 8
plt.axvline(x=xy, c=lc, lw=lw, zorder=1)
plt.axhline(y=xy, c=lc, lw=lw, zorder=1)

xy = 18
plt.axvline(x=xy, c=lc, lw=lw, zorder=1)
plt.axhline(y=xy, c=lc, lw=lw, zorder=1)

xy = 27
plt.axvline(x=xy, c=lc, lw=lw, zorder=1)
plt.axhline(y=xy, c=lc, lw=lw, zorder=1)


plt.gca().set_aspect('equal')
plt.gca().invert_xaxis()
plt.gca().invert_yaxis()
# Out:
# (900, 12)

# %%
# Out:
# dict_keys(['ND', 'HFD8', 'HFD14'])

# %%
df = df[df['n_overlap'] > 0]
df = df.sort_values(by=['key1', 'key2', 'n_overlap'], ascending=[False, False, False])
print(df.shape)
df

# %%
# ?gget.enrichr

# %%
mm = cf[cf['cellType'].isin(['Monocytes', 'Macrophages'])].reset_index(drop=True)

t = mm[['cellType', 'clusterId', 'key']].drop_duplicates()
t = t.sort_values(by=['key', 'cellType'], ascending=[False, True])

grped = t.groupby(['cellType', 'key'])['clusterId'].count().reset_index()
grped = grped.sort_values(by=['key', 'cellType'], ascending=[False, True])
print(tabulate.tabulate(grped, showindex=False))
print()
print(tabulate.tabulate(t, headers=t.columns, showindex=False))

# %%
# ?tabulate.tabulate
