# %%
import os
import pandas as pd
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc
from collections import Counter
import squidpy as sq
from scipy.spatial.distance import pdist, squareform
import scipy
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
from sklearn import metrics
import tabulate
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram
import itertools
import umap
from importlib import reload
from scipy import stats
import matplotlib.image as mpimg
import gget

# locals
import utils as ut
reload(ut)
# Out:
# 2022-11-21 12:36:52.939415: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-21 12:36:53.073366: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/slurm/lib64:
# 2022-11-21 12:36:53.073392: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-11-21 12:36:53.098907: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-21 12:36:54.870489: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/slurm/lib64:
# 2022-11-21 12:36:54.870592: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/slurm/lib64:
# 2022-11-21 12:36:54.870599: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# <module 'utils' from '/home/cstansbu/git_repositories/spatial_transcriptomics/clustering/utils.py'>

# %%
clusterPath = "/nfs/turbo/umms-indikar/shared/projects/spatial_transcriptomics/data/scanpy/clusters.csv"
cf = pd.read_parquet(clusterPath)
print(cf.shape)
print(cf['cellType'].unique())
cf.head()
# Out:
# (427882, 7)
# ['Macrophages' 'B cells' 'Monocytes' 'NK cells' 'Dendritic cells'
#  'T cells' 'Stromal cells']
#      gene     scores          pvals  logfoldchanges  clusterId key  \
# 0  H2-EB1  36.343353  4.575346e-181        3.564091          1  ND
# 1   H2-AA  35.311523  4.761517e-183        3.430534          1  ND
# 2  H2-AB1  34.411163  2.815112e-177        3.234597          1  ND
# 3    CD74  33.910587  2.451588e-177        3.302062          1  ND
# 4  H2-DMA  31.695400  2.991793e-123        2.667091          1  ND
#
#       cellType
# 0  Macrophages
# 1  Macrophages
# 2  Macrophages
# 3  Macrophages
# 4  Macrophages

# %%
t = cf[['cellType', 'clusterId', 'key']].drop_duplicates()
t = t.groupby(['cellType', 'key'])['clusterId'].count().reset_index()
t = t.sort_values(by=['key', 'cellType'], ascending=[False, True])

colorlist = ut.ncolor(3, cmap='viridis')


plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 5, 3

sns.barplot(data=t,
            y='clusterId',
            x='cellType',
            hue='key',
            edgecolor='k',
            palette=colorlist)

plt.ylabel("Number of Clusters")
plt.xlabel("")
_ = plt.xticks(rotation=45)

ax = plt.gca()
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles[0:], labels=labels[0:])

# t = pd.pivot_table(t, values='clusterId', index=['cellType'],
#                     columns=['key']).reset_index()

# # reorder columns
# t = t[['cellType', 'ND', 'HFD8', 'HFD14']].rename(columns={'cellType' : 'Cell Type'})

# print(tabulate.tabulate(t,  headers=t.columns, tablefmt='latex'))

# %%
""" get ND cells """
alpha = 0.05
# cellType = 'Macrophages'
cellType = 'Monocytes'

keys = ['ND', 'HFD8', 'HFD14']

res = {}

for key in keys:

    t = cf[cf['cellType'] == cellType].reset_index(drop=True)
    t = t[t['key'] == key].reset_index(drop=True)
    nClusters = t['clusterId'].nunique()
    t['geneCount'] = t.groupby('gene')['clusterId'].transform('count')

    t = t[t['pvals'] < alpha] # only singificant results

    uni = t[t['geneCount'] < 2] # single cluster
    shared = t[t['geneCount'] > (nClusters-1)] # all clusters
    
    print(key)
    print(f"{uni.shape} {uni['gene'].nunique()}")
    print(f"{shared.shape} {shared['gene'].nunique()}")
    
    res[key] = [uni, shared]
    
    print()
# Out:
# ND
# (5037, 8) 5037
# (5697, 8) 1899
#
# HFD8
# (2464, 8) 2464
# (9156, 8) 2289
#
# HFD14
# (4127, 8) 4127
# (7980, 8) 2660

# %%
"""shared gene analysis """
n = 500
lft = 1
db = 'celltypes'
keys = ['ND', 'HFD8', 'HFD14']

allMarker = []
allLF = []

for key in keys:
    uni, shared = res[key]
    shared = shared.sort_values(by='scores', ascending=False)
    genes = shared['gene'].head(n).to_list()
    
    lfGenes = list(set(shared[shared['logfoldchanges'] > lft]['gene'].to_list()))
    allLF += lfGenes
    kegg = gget.enrichr(genes, database=db)
    
    # get genes for the cell type pathway
    mGenes = kegg[kegg['path_name'] == cellType]['overlapping_genes'].values[0]
    allMarker += mGenes
    print(key, len(mGenes))
    print(kegg[['path_name', 'p_val']].head(10))
    print()
    

# genes with LFC > lft in ll three times points
allLF = pd.DataFrame.from_dict(Counter(allLF), orient='index', columns=['count']).reset_index()
allLF = allLF[allLF['count'] > 2]['index'].to_list()
print(", ".join(sorted(allLF)))
print()

# genes also included in the celltype
allMarker = pd.DataFrame.from_dict(Counter(allMarker), orient='index', columns=['count']).reset_index()
allMarker = allMarker[allMarker['count'] > 2]['index'].to_list()
print(", ".join(sorted(allMarker)))
# Out:
# Mon Nov 21 12:36:58 2022 INFO Performing Enichr analysis using database PanglaoDB_Augmented_2021.
#     Please note that there might a more appropriate database for your application.
#     Go to https://maayanlab.cloud/Enrichr/#libraries for a full list of supported databases.
#
# Mon Nov 21 12:36:59 2022 INFO Performing Enichr analysis using database PanglaoDB_Augmented_2021.
#     Please note that there might a more appropriate database for your application.
#     Go to https://maayanlab.cloud/Enrichr/#libraries for a full list of supported databases.
# ND 22
#          path_name         p_val
# 0      Macrophages  1.402180e-12
# 1        Monocytes  3.602153e-12
# 2    Kupffer Cells  1.479295e-10
# 3      Neutrophils  7.470414e-10
# 4        Platelets  1.082288e-09
# 5      Osteoclasts  2.587431e-09
# 6  Dendritic Cells  1.069673e-08
# 7        Microglia  1.073864e-08
# 8   Megakaryocytes  1.663566e-08
# 9      Eosinophils  2.240874e-08
# Mon Nov 21 12:37:00 2022 INFO Performing Enichr analysis using database PanglaoDB_Augmented_2021.
#     Please note that there might a more appropriate database for your application.
#     Go to https://maayanlab.cloud/Enrichr/#libraries for a full list of supported databases.
# HFD8 15
#                     path_name         p_val
# 0                   Microglia  8.419522e-13
# 1             Dendritic Cells  7.961476e-12
# 2  Osteoclast Precursor Cells  1.284534e-11
# 3                 Macrophages  9.695629e-11
# 4            Langerhans Cells  1.116083e-10
# 5               Kupffer Cells  4.900317e-09
# 6        Alveolar Macrophages  8.028645e-08
# 7                   Monocytes  1.444697e-07
# 8        Red Pulp Macrophages  1.794600e-07
# 9                 Osteoclasts  5.108729e-07
#
# HFD14 32
#                           path_name         p_val
# 0                       Macrophages  2.193935e-21
# 1                         Monocytes  1.925414e-20
# 2                   Dendritic Cells  9.428741e-20
# 3                       Neutrophils  2.532022e-19
# 4  Myeloid-derived Suppressor Cells  1.721119e-18
# 5              Alveolar Macrophages  2.263496e-16
# 6      Plasmacytoid Dendritic Cells  2.638576e-16
# 7                       Eosinophils  5.471874e-14
# 8                     Kupffer Cells  2.752402e-13
# 9                         Microglia  6.700476e-13
#
# MS4A4C, MS4A6B, PGLYRP1, SRGN
#
# NCF2

# %%
break
# Out:
#   File "/tmp/ipykernel_2760470/668683560.py", line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
"""Next we look at unique genes """

lft = 1
db = 'celltypes'
keys = ['ND', 'HFD8', 'HFD14']

plt.rcParams['figure.dpi'] = 300


for key in keys:
    uni, shared = res[key]
    
    
    # add LF flag
    uni['lfc'] = np.where(uni['logfoldchanges'] > lft, 1, 0)
    
    # DE genes
    gr = uni.groupby(['clusterId']).agg(
        nGene = ('gene', 'count'),
        lfcGene = ('lfc', 'sum') 
    ).reset_index()
    
    gr = gr.sort_values(by='clusterId')
    
    
    gr['label'] = gr.index + 1
    gr['label'] = gr['label'].apply(lambda x: f"Cluster {x}")
    
    
    gr = gr[['label', 'nGene', 'lfcGene']].rename(columns={'label' : 'Cluster', 
                                                           'nGene': 'DE Genes', 
                                                           'lfcGene': f'LFC > {lft}'})
    
    print(tabulate.tabulate(gr, headers=gr.columns, tablefmt='latex'))
    print()
    # genes = gr['nGene'].to_list()
    # labels = gr['label'].to_list()
    
#     print(gr)
#     print()
    
#     k = len(gr)
#     colorlist = ut.ncolor(k, cmap='Spectral')
    
    
#     plt.rcParams['figure.figsize'] =  3, (k / 2)
    
#     fig, ax = plt.subplots()
    
#     ax.barh(labels,
#            genes,
#            edgecolor='k',
#            color=colorlist)
    
#     ax.set_xlabel('DE Genes')
#     ax.set_ylabel('')
#     ax.invert_yaxis()
    
#     plt.show()
#     print()

# %%
"""Next we look at unique genes """

lft = 1
alpha = 0.05
# db = 'WikiPathways_2019_Mouse'
# db = 'KEGG_2019_Mouse'
db = 'ontology'

keys = ['ND', 'HFD8', 'HFD14']

plt.rcParams['figure.dpi'] = 300

lfGene = {}
allGene = {}
dfList = []


for key in keys:
    uni, shared = res[key]
    
    
    for cid in uni['clusterId'].unique():
        t = uni[uni['clusterId'] == cid]
        
        t = t.sort_values(by='logfoldchanges', ascending=False)
        mGenes = t['gene'].to_list()
        
        if not key in allGene:
            allGene[key] = {cid: mGenes}
        else:
            allGene[key][cid] = mGenes
        
        # genes passing lf filter
        t = t[t['logfoldchanges'] > lft]
        
        if len(t) > 0:
            t = t.sort_values(by='logfoldchanges', ascending=False)
            lfcGenes = t['gene'].to_list()

            if not key in lfGene:
                lfGene[key] = {cid: lfcGenes}
            else:
                lfGene[key][cid] = lfcGenes

        # enrichment analysis
        ef = gget.enrichr(mGenes, database=db)
        ef = ef[ef['p_val'] < alpha]
        ef['key'] = key
        ef['clusterId'] = cid
        ef['allDEG'] = ", ".join(mGenes)
        ef['LFCGenes'] = ", ".join(lfcGenes)
        dfList.append(ef)
        
df = pd.concat(dfList, ignore_index=True)
print(df.shape)
outpath = f"/nfs/turbo/umms-indikar/shared/projects/spatial_transcriptomics/data/scanpy/{cellType}_DE_{db}.csv"
df.to_csv(outpath, index=False)
df.head()

# %%
# keys = ['ND', 'HFD8', 'HFD14']

# res = []


# for key in keys:
#     uni, shared = res[key]
    
    
    
#     for cid in uni['clusterId'].unique():
        
#         cdf = uni[uni['clusterId'] == cid]
#         cdf = cdf.sort_values(by='logfoldchanges', ascending=False)
        
#         mGenes = ", ".join(cdf['gene'].to_list())
        
#         row = {
#             'time' : key,
#             'clusterId' : 
#         }
        
        
        
        
#         print(cid, "\t&\t", ", ".join(mGenes))
#         # print("\n".join(mGenes))
#         # print()

# %%
nd = df[df['key'] == 'ND'].reset_index(drop=True)
nd['nOverlap'] = nd['overlapping_genes'].apply(lambda x: len(x))

for i, cid in enumerate(nd['clusterId'].unique()):
    
    cdf = nd[nd['clusterId'] == cid]
    
    for j in range(8):
        print(f"{cid} cluster {i+1}", cdf.iloc[j]['path_name'])
        
    print()

# %%
lft = 1.5
keys = ['ND', 'HFD8', 'HFD14']

allGene = {}

for key in keys:
    uni, shared = res[key]
    
    for cid in uni['clusterId'].unique():
        uniG = uni[(uni['clusterId'] == cid) & (uni['logfoldchanges'] > lft)]
        uniG = uniG['gene'].to_list()
        
            
        sharedG = shared[(shared['clusterId'] == cid) & (shared['logfoldchanges'] > lft)]
        sharedG = sharedG['gene'].to_list()
        
        print(f"{key} {cid} {len(uniG)} {len(sharedG)}")
        
        mGenes = list(set(uniG + sharedG))
        
        
        if not key in allGene:
            allGene[key] = {cid: mGenes}
        else:
            allGene[key][cid] = mGenes

        
print('done')

# %%
newRows = []

for ti in allGene.keys():
    for tj in allGene.keys():
        for ci in allGene[ti]:
            for cj in allGene[tj]:


                di = set(allGene[ti][ci])
                dj = set(allGene[tj][cj])

                overlap = di.intersection(dj)

                row = {
                    'key1' : ti,
                    'key2' : tj,
                    'cid1' : ci,
                    'cid2' : cj,
                    'l1' : f"{ti}_{ci}",
                    'l2' : f"{tj}_{cj}",
                    'n1' : len(di),
                    'n2' : len(dj),
                    'n_overlap' : len(overlap),
                    'overlap' : list(overlap)

                }

                newRows.append(row)

df = pd.DataFrame(newRows)
print(df.shape)

df.head()

k = pd.pivot_table(df, 
                   values='n_overlap', 
                   index=['l1'],
                   columns=['l2'])

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 15, 15
plt.rcParams['figure.facecolor'] = "w"

sns.heatmap(k,
            annot=True, 
            linewidth=.5,
            linecolor='lightgrey',
            # vmin=0,
            vmax=np.quantile(k, 0.95),
            cbar=True,
            cmap='Reds',
            cbar_kws={'fraction' : 0.046, 
                      'pad' : 0.04, 
                      'label' : 'n Overlapping Genes'},
            fmt=".1f",
            zorder=1)

plt.ylabel("")
plt.xlabel("")

# label each time point
colorlist = ut.ncolor(3, cmap='viridis')

fillalpha = 0.4

ll = 7
ul = 20
nclusters = len(k.columns)

plt.axvline(x=ll, c='k', lw=2)
plt.axhline(y=ll, c='k', lw=2)
# plt.axvspan(xmin=ll, 
#             xmax=ul, 
#             ymin=1-(ll/nclusters), 
#             ymax=1-(ul/nclusters),
#             color=colorlist[0],
#             alpha=fillalpha, 
#             zorder=2)

ll = 3
ul = 7
plt.axvline(x=ll, c='k', lw=2)
plt.axhline(y=ll, c='k', lw=2)
# plt.axvspan(xmin=ll, 
#             xmax=ul, 
#             ymin=1-(ll/nclusters), 
#             ymax=1-(ul/nclusters),
#             color=colorlist[1],
#             alpha=fillalpha, 
#             zorder=2)


# ll = 0
# ul = 8
# plt.axvspan(xmin=ll, 
#             xmax=ul, 
#             ymin=1-(ll/nclusters), 
#             ymax=1-(ul/nclusters),
#             color=colorlist[2],
#             alpha=fillalpha, 
#             zorder=2)

plt.gca().set_aspect('equal')

# %%
break

# %%
df = df[df['n_overlap'] > 0]
df = df.sort_values(by=['key1', 'key2', 'n_overlap'], ascending=[False, False, False])
print(df.shape)
df

# %%
# ?gget.enrichr

# %%
mm = cf[cf['cellType'].isin(['Monocytes', 'Macrophages'])].reset_index(drop=True)

t = mm[['cellType', 'clusterId', 'key']].drop_duplicates()
t = t.sort_values(by=['key', 'cellType'], ascending=[False, True])

grped = t.groupby(['cellType', 'key'])['clusterId'].count().reset_index()
grped = grped.sort_values(by=['key', 'cellType'], ascending=[False, True])
print(tabulate.tabulate(grped, showindex=False))
print()
print(tabulate.tabulate(t, headers=t.columns, showindex=False))

# %%
# ?tabulate.tabulate
