# %%
import pandas as pd
import numpy as np
import os
import sys
import scanpy as sc

# %%
fpath = "/nfs/turbo/umms-indikar/shared/projects/spatial_transcriptomics/data/anndata_object/all_cells.h5ad"

adata = sc.read_h5ad(fpath)
adata
# Out:
# /home/cstansbu/.local/lib/python3.9/site-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# AnnData object with n_obs × n_vars = 13820 × 31053
#     obs: 'cellType', 'sampleInfo', 'x', 'y', 'colors'
#     var: 'gene_name'

# %%
# Out:
#                                  cellType sampleInfo         x         y  \
# cellId
# AAACGAACAGCAGTAG.1_ND             B cells         ND  6.783486  1.839065
# AAAGAACGTCTACAGT.1_ND                Mac1         ND  3.089298 -1.726030
# AAAGAACTCCTCGCAT.1_ND                Mac1         ND  3.614130 -1.571004
# AAAGGGCGTTAGGGTG.1_ND                Mac3         ND  3.086352  6.166065
# AACAAAGAGTATAGGT.1_ND           Monocytes         ND  3.178745  4.929769
# ...                                   ...        ...       ...       ...
# TTTGTTGGTCGTTATG.1_HFD14  Dendritic cells      HFD14  4.670653  6.759196
# TTTGTTGGTTAGGAGC.1_HFD14             Mac5      HFD14 -3.973560 -0.789964
# TTTGTTGTCACGAACT.1_HFD14             Mac4      HFD14 -0.134358 -1.523886
# TTTGTTGTCGACCTAA.1_HFD14             Mac5      HFD14 -3.153590 -0.436724
# TTTGTTGTCTGGGCCA.1_HFD14             Mac5      HFD14 -3.970749  0.267423
#
#                            colors
# cellId
# AAACGAACAGCAGTAG.1_ND     #9e0142
# ...
