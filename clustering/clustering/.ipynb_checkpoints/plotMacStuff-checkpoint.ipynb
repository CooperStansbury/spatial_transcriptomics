# %%
import os
import pandas as pd
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns
from textwrap import wrap
import scipy
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
from sklearn import metrics
import itertools
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from scipy.sparse import csgraph
import umap
from sklearn import linear_model
from collections import Counter
import sklearn
import scipy.stats as sps
from scipy.spatial.distance import cdist
from importlib import reload
import mygene
import sys
import gget

# locals
sys.path.append("../")
import utils as ut
reload(ut)
# Out:
# 2023-06-13 09:39:18.507310: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-13 09:39:22.628008: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-06-13 09:39:22.628040: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-06-13 09:39:22.654828: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-06-13 09:39:25.703382: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-06-13 09:39:25.703680: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-06-13 09:39:25.703690: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# <module 'utils' from '/home/cstansbu/git_repositories/spatial_transcriptomics/clustering/clustering/../utils.py'>

# %%
cardDir =  "/nfs/turbo/umms-indikar/shared/projects/spatial_transcriptomics/data/CARDInputs/"
xyPath =  "/nfs/turbo/umms-indikar/shared/projects/spatial_transcriptomics/data/combinedEmbedding.csv"
xy = pd.read_csv(xyPath)
cTypes = sorted(list(xy['cellTypes'].unique()))
xy['metaTypes'] = xy['cellTypes']

macTypes = [
    "Mac1",
    "Mac2",
    "Mac3", 
    "Mac4",
    "Mac5",
]

keys = ['ND', 'HFD8', 'HFD14']

df = []
rna = {}

for key in keys:
    print(f"{key}...")
    labelPath = f"{cardDir}{key}_macrophage_clusters.csv"
    lf = pd.read_csv(labelPath)
    lf = lf[lf['cellType'].isin(macTypes)]
    
    lf = pd.merge(lf, xy[['x', 'y', 'cellId', 'colors', 'metaTypes']], 
                  how='left',
                  left_on='cellId',
                  right_on='cellId')
    
    df.append(lf)
    
    rnaPath = f"{cardDir}{key}_macrophage_rna.csv"
    rf = pd.read_csv(rnaPath)
    rf = rf.T

    
    new_header = rf.iloc[0] 
    rf = rf[1:] 
    rf.columns = new_header 
    rf.index.names = ['cellId']
    rf = rf[rf.index.isin(lf['cellId'].to_list())]
    
    rf = ut.normalize(rf, 1e6)
    
    rna[key] = rf
    

df = pd.concat(df)
print('done')
# Out:
# ND...
# HFD8...

# %%
macTypes = [
    "Mac1",
    "Mac2",
    "Mac3", 
    "Mac4",
    "Mac5",
]

pdf = df[df['cellType'].isin(macTypes)]
pdf.head()
# Out:
#                cellId cellType sampleInfo         x         y   colors
# 0  AAAGAACGTCTACAGT.1     Mac1         ND  3.089298 -1.726030  #fdbf6f  \
# 1  AAAGAACTCCTCGCAT.1     Mac1         ND  3.614130 -1.571004  #fdbf6f
# 2  AAAGGGCGTTAGGGTG.1     Mac3         ND  3.086352  6.166065  #fdbf6f
# 3  AACAAAGCACCGGCTA.1     Mac3         ND  4.344001  5.801922  #fdbf6f
# 4  AACAAAGGTTCACGAT.1     Mac1         ND  0.130051 -1.583494  #fdbf6f
#
#      metaTypes
# 0  Macrophages
# 1  Macrophages
# 2  Macrophages
# 3  Macrophages
# 4  Macrophages

# %%
gx = pdf.groupby(['cellType', 'sampleInfo'])['cellId'].count().reset_index(drop=False)
gx.columns = ['cellType', 'key', 'count']
gx = gx.sort_values(by=['key', 'cellType'], ascending=[False, True])

keyMap = {
    'ND' : 'ND',
    'HFD8' : '8w',
    'HFD14' : '14w',
}

gx['keyName'] = gx['key'].map(keyMap)

colors = [
    '#9835e4',
    '#e48035',
    '#8e0152',
    '#9acd61',
    '#276419',
]


plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 2, 3
plt.rcParams['figure.facecolor'] = "w"

sns.barplot(data=gx, 
            x='keyName',
            y='count',
            ec='k',
            hue='cellType',
            palette=colors)

plt.xlabel("")
plt.ylabel("n Cells")
sns.despine()

plt.gca().legend().remove()

# sns.move_legend(plt.gca(),
#                 title="",
#                 loc='upper right',
#                 frameon=False,
#                 bbox_to_anchor=(1.7, 1.05))

# %%
break
# Out:
#   Cell In[5], line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
res = []


for key in keys:
    rf = rna[key].reset_index(drop=False)
    rf['key'] = key
    rf = pd.merge(rf, df[['cellId', 'cellType']],
                  how='left', 
                  left_on='cellId', 
                  right_on=['cellId'])
    res.append(rf)
    
res = pd.concat(res)
res = pd.melt(res, id_vars=['key', 'cellId', 'cellType'],
              value_vars=genes,
              var_name='gene')

res['logex'] = np.log1p(res['value'].fillna(0).astype(float))
res['geneName'] = res['gene'].apply(lambda x: str(x).lower().capitalize())

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.figsize'] = 3.5, 1.5
plt.rcParams['figure.facecolor'] = "w"

sns.barplot(data=res, 
              x='geneName',
              y='logex',
              dodge=True,
              ec='k',
              ci=None,
              # showfliers=False,
              zorder=3,
              hue='cellType',
              palette=colors)

plt.xlabel("")
plt.ylabel("Expression (log)")
sns.despine()
plt.grid(True, zorder=1)

plt.gca().legend().remove()
plt.xticks(rotation=90)

# sns.move_legend(plt.gca(),
#                 title="",
#                 loc='upper right',
#                 frameon=False,
#                 bbox_to_anchor=(1.7, 1.05))
# Out:
# /tmp/ipykernel_3867349/78390947.py:25: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=res,
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Cd9'),
#   Text(1, 0, 'Itgax'),
#   Text(2, 0, 'Mrc1'),
#   Text(3, 0, 'Lgals3'),
#   Text(4, 0, 'Mmp12'),
#   Text(5, 0, 'Trem2')])
