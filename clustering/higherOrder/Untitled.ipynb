# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns
import gget

from sklearn.feature_extraction.text import CountVectorizer

import sys
sys.path.append('../')
import utils as ut

# %%
outpath = "/nfs/turbo/umms-indikar/shared/projects/spatial_transcriptomics/data/kronecker_stuff/A.csv"
df = pd.read_csv(outpath)
print('done')
# Out:
# done

# %%
# df.head()
# df['AAACAAGTATCTCCCA.1_HFD8']

# %%
df.head()
# Out:
#         Unnamed: 0  AAACAAGTATCTCCCA.1_HFD8  AAACACCAATAACTGC.1_HFD8
# 0          B cells                 0.024186                 0.055559  \
# 1  Dendritic cells                 0.032415                 0.053272
# 2             Mac1                 0.013933                 0.031294
# 3             Mac2                 0.054497                 0.092979
# 4             Mac3                 0.028032                 0.040925
#
#    AAACAGCTTTCAGAAG.1_HFD8  AAACAGGGTCTATATT.1_HFD8  AAACAGTGTTCCTGGG.1_HFD8
# 0                 0.060818                 0.061966                 0.050160  \
# 1                 0.058550                 0.077268                 0.044582
# 2                 0.034728                 0.029132                 0.038070
# 3                 0.083246                 0.102811                 0.078635
# 4                 0.041195                 0.068334                 0.040965
#
#    AAACATGGTGAGAGGA.1_HFD8  AAACATTTCCCGGATT.1_HFD8  AAACCGGGTAGGTACC.1_HFD8
# 0                 0.067553                 0.063429                 0.041635  \
# 1                 0.063340                 0.065055                 0.063896
# 2                 0.034443                 0.026242                 0.055456
# 3                 0.087423                 0.082949                 0.079707
# 4                 0.052579                 0.056174                 0.034099
#
#    AAACCGTTCGTCCAGG.1_HFD8  ...  TTGTGTATGCCACCAA.1_HFD8
# 0                 0.058330  ...                 0.054895  \
# 1                 0.055766  ...                 0.050710
# 2                 0.055782  ...                 0.034487
# 3                 0.101680  ...                 0.099910
# 4                 0.045637  ...                 0.040345
#
#    TTGTGTTTCCCGAAAG.1_HFD8  TTGTTAGCAAATTCGA.1_HFD8  TTGTTCAGTGTGCTAC.1_HFD8
# 0                 0.073239                 0.049903                 0.076856  \
# 1                 0.077514                 0.062987                 0.077887
# 2                 0.022748                 0.035908                 0.038526
# 3                 0.082904                 0.085098                 0.085527
# 4                 0.045914                 0.047336                 0.050311
#
#    TTGTTGGCAATGACTG.1_HFD8  TTGTTGTGTGTCAAGA.1_HFD8  TTGTTTCACATCCAGG.1_HFD8
# 0                 0.055797                 0.055307                 0.034402  \
# 1                 0.075959                 0.079574                 0.037182
# 2                 0.031090                 0.048917                 0.041415
# 3                 0.067563                 0.097790                 0.075080
# 4                 0.047268                 0.067441                 0.028201
#
#    TTGTTTCATTAGTCTA.1_HFD8  TTGTTTCCATACAACT.1_HFD8  TTGTTTGTATTACACG.1_HFD8
# 0                 0.052445                 0.045346                 0.044830
# 1                 0.051823                 0.041531                 0.029720
# 2                 0.036955                 0.040251                 0.040553
# 3                 0.079588                 0.083326                 0.069046
# 4                 0.044238                 0.033342                 0.025978
#
# [5 rows x 3395 columns]
