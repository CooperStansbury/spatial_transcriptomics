# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import os
import scipy.stats
import networkx as nx
from sklearn import metrics
from sklearn.neighbors import NearestNeighbors
from sklearn.neighbors import radius_neighbors_graph
import matplotlib.patches as mpatches
import sklearn.neighbors
from scipy.spatial import distance
from skimage.filters import unsharp_mask
from skimage.color import rgb2gray
from collections import Counter
import skimage
from Bio import SeqIO
from Bio.KEGG import REST
from Bio.KEGG.KGML import KGML_parser
import io

# %%
cardOutDir = "/nfs/turbo/umms-indikar/shared/projects/spatial_transcriptomics/data/CARDOuputs/"

dfList = []

for f in os.listdir(cardOutDir):
    if not 'macrophage' in f:
        fullPath = f"{cardOutDir}{f}"
        key = f.split("_")[0]
        df = pd.read_csv(fullPath)
        df = df.rename(columns={'Unnamed: 0' : 'spotId'})
        df['key'] = key
        dfList.append(df)

df = pd.concat(dfList, ignore_index=True)
print(f"{df.shape=}")
print(df['key'].value_counts())
print()
df.head()
# Out:
# df.shape=(14840, 9)
# HFD8     6784
# ND       4070
# HFD14    3986
# Name: key, dtype: int64
#                spotId   B cells  Macrophages  Monocytes   T cells  NK cells  \
# 0  AAACAAGTATCTCCCA.1  0.186695     0.075988   0.052869  0.012651  0.008352
# 1  AAACAGCTTTCAGAAG.1  0.005391     0.001864   0.021828  0.000505  0.000616
# 2  AAACAGGGTCTATATT.1  0.106028     0.042763   0.145105  0.011063  0.010809
# 3  AAACATTTCCCGGATT.1  0.125786     0.028988   0.063324  0.007038  0.012788
# 4  AAACCCGAACGAAATC.1  0.148198     0.026439   0.075444  0.002402  0.012780
#
#    Stromal cells  Dendritic cells key
# 0       0.662812         0.000635  ND
# 1       0.969331         0.000464  ND
# 2       0.681758         0.002473  ND
# 3       0.761152         0.000924  ND
# 4       0.734703         0.000034  ND

# %%
coordDir = "/nfs/turbo/umms-indikar/shared/projects/spatial_transcriptomics/data/CARDInputs/"

dfList = []

for f in os.listdir(coordDir):
    if "coord" in f:
        fullPath = f"{coordDir}{f}"
        key = f.split("_")[0]
        cdf = pd.read_csv(fullPath)
        cdf = cdf.rename(columns={'Unnamed: 0' : 'spotId'})
        cdf['key'] = key
        dfList.append(cdf)

cdf = pd.concat(dfList, ignore_index=True)
print(f"{cdf.shape=}")
print(cdf['key'].value_counts())
print()
cdf.head()
# Out:
# cdf.shape=(14848, 4)
# HFD8     6788
# ND       4072
# HFD14    3988
# Name: key, dtype: int64
#                spotId            x            y    key
# 0  AAACATTTCCCGGATT.1  1139.783401  1365.804581  HFD14
# 1  AAACCGGGTAGGTACC.1   468.056902  1045.415505  HFD14
# 2  AAACCGTTCGTCCAGG.1   604.524374  1214.452428  HFD14
# 3  AAACCTAAGCAGCCGG.1  1003.708924  1433.743571  HFD14
# 4  AAACCTCATGAAGTTG.1   380.369919   960.970730  HFD14

# %%
"""Merge CARD predictions with spatial coordinates"""
df = pd.merge(cdf, df,
              how='left', 
              left_on=['spotId', 'key'],
              right_on=['spotId', 'key'])

df = df.fillna(0)
df = df.drop_duplicates() # very important!
print(df['key'].value_counts())
df.head()
# Out:
# HFD8     3394
# ND       2036
# HFD14    1994
# Name: key, dtype: int64
#                spotId            x            y    key   B cells  Macrophages  \
# 0  AAACATTTCCCGGATT.1  1139.783401  1365.804581  HFD14  0.173383     0.273179
# 2  AAACCGGGTAGGTACC.1   468.056902  1045.415505  HFD14  0.106977     0.537826
# 4  AAACCGTTCGTCCAGG.1   604.524374  1214.452428  HFD14  0.140694     0.238721
# 6  AAACCTAAGCAGCCGG.1  1003.708924  1433.743571  HFD14  0.163235     0.144935
# 8  AAACCTCATGAAGTTG.1   380.369919   960.970730  HFD14  0.157633     0.320428
#
#    Monocytes   T cells  NK cells  Stromal cells  Dendritic cells
# 0   0.092979  0.059718  0.054731       0.260206         0.085804
# 2   0.172027  0.036994  0.019694       0.042619         0.083865
# 4   0.227167  0.063076  0.111028       0.132378         0.086937
# 6   0.159598  0.129796  0.217486       0.077548         0.107403
# 8   0.192115  0.060545  0.111355       0.108417         0.049506

# %%
def drawPieMarker(xs, ys, ratios, sizes, colors):
    assert sum(ratios) <= 1, 'sum of ratios needs to be < 1'

    markers = []
    previous = 0
    # calculate the points of the pie pieces
    for color, ratio in zip(colors, ratios):
        this = 2 * np.pi * ratio + previous
        x  = [0] + np.cos(np.linspace(previous, this, 10)).tolist() + [0]
        y  = [0] + np.sin(np.linspace(previous, this, 10)).tolist() + [0]
        xy = np.column_stack([x, y])
        previous = this
        markers.append({'marker' : xy, 
                        's' : np.abs(xy).max()**2*np.array(sizes), 
                        'facecolor' : color,
                        'linewidth' : 0.2,
                        'edgecolor' : 'k'})

    # scatter each of the pie pieces to create pies
    for marker in markers:
        ax.scatter(xs, ys, **marker)

key = 'ND'

kdf = df[df['key'] == key].reset_index(drop=True)
cols = [
    'x', 'y', 
    'B cells', 
    'Macrophages',
    'Dendritic cells',
]
kdf = kdf[cols]
kdf['other'] = 1 - kdf[['B cells', 'Macrophages','Dendritic cells']].sum(axis=1)
kdf.head()
colors = ['green', 'orange', 'purple', 'lightgray']

plt.rcParams['figure.dpi'] = 300
plt.rcParams['figure.facecolor'] = "w"
plt.rcParams['figure.figsize'] = 8, 8
fig, ax = plt.subplots()


kdf = kdf[(kdf['x'] > 400) & (kdf['x'] < 900)]
kdf = kdf[(kdf['y'] > 400) & (kdf['y'] < 900)]
print(f"{kdf.shape=}")

for idx, row in kdf.iterrows():    
    x = row['x']
    y = row['y']
    ratios = row[['B cells', 'Macrophages','Dendritic cells', 'other']].values
    
    drawPieMarker(xs=x,
                  ys=y,
                  ratios=ratios,
                  sizes=250,
                  colors=colors)
    
    
ax = plt.gca()
ax.invert_yaxis()
ax.set_xticks([])
ax.set_yticks([])

# ax.scatter(kdf['x'], kdf['y'], c='k', marker=".", zorder=1)

sns.despine(left=True, bottom=True)
# Out:
# kdf.shape=(300, 6)

# %%
def drawPieMarker(xs, ys, ratios, sizes, colors):
    assert sum(ratios) <= 1, 'sum of ratios needs to be < 1'

    markers = []
    previous = 0
    # calculate the points of the pie pieces
    for color, ratio in zip(colors, ratios):
        this = 2 * np.pi * ratio + previous
        x  = [0] + np.cos(np.linspace(previous, this, 10)).tolist() + [0]
        y  = [0] + np.sin(np.linspace(previous, this, 10)).tolist() + [0]
        xy = np.column_stack([x, y])
        previous = this
        markers.append({'marker':xy, 's':np.abs(xy).max()**2*np.array(sizes), 'facecolor':color})

    # scatter each of the pie pieces to create pies
    for marker in markers:
        ax.scatter(xs, ys, **marker)


fig, ax = plt.subplots()
drawPieMarker(xs=np.random.rand(1),
              ys=np.random.rand(1),
              ratios=[.1, .2, .1, 0.1],
              sizes=1000,
              colors=['cyan', 'orange', 'teal', 'red'])

# %%
# ?sns.despine
# Out:
# Signature:
# sns.despine(
#     fig=None,
#     ax=None,
#     top=True,
#     right=True,
#     left=False,
#     bottom=False,
#     offset=None,
#     trim=False,
# )
# Docstring:
# Remove the top and right spines from plot(s).
#
# fig : matplotlib figure, optional
#     Figure to despine all axes of, defaults to the current figure.
# ax : matplotlib axes, optional
#     Specific axes object to despine. Ignored if fig is provided.
# top, right, left, bottom : boolean, optional
#     If True, remove that spine.
# offset : int or dict, optional
#     Absolute distance, in points, spines should be moved away
#     from the axes (negative values move spines inward). A single value
#     applies to all spines; a dict can be used to set offset values per
#     side.
# trim : bool, optional
#     If True, limit spines to the smallest and largest major tick
#     on each non-despined axis.
#
# Returns
# -------
# None
# File:      /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages/seaborn/utils.py
# Type:      function
